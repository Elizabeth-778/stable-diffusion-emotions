# %% [markdown]
# Min-Dalle https://github.com/kuprel/min-dalle \\
# is a smaller version of OpenAI's DALL·E model \\
# The seed parameter is a numerical value that initializes the generation of an image. The seed parameter’s most significant attribute is its ability to reproduce the same image when used with the same parameters and prompt. This reproducibility is crucial in AI, especially when experimenting with different parameters or variations.

# %%
! pip install min-dalle -q
# Out:
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 433.8/433.8 kB 3.1 MB/s eta 0:00:00
# ...

# %%
from min_dalle import MinDalle

model = MinDalle(is_mega=True, is_reusable=True)
# Out:
# using device cuda
# downloading tokenizer params
# intializing TextTokenizer
# downloading encoder params
# initializing DalleBartEncoder
# downloading decoder params
# initializing DalleBartDecoder
# downloading detokenizer params
# initializing VQGanDetokenizer

# %%
# %%time

text = "awe inspiring landscape"
seed = 6
grid_size = 2

display(model.generate_image(text, seed, grid_size))
# Out:
# <PIL.Image.Image image mode=RGB size=512x512>
# CPU times: user 29.5 s, sys: 192 ms, total: 29.6 s
# Wall time: 31.2 s

# %%
# %%time

text = "happy broccoli"
seed = 6
grid_size = 2

display(model.generate_image(text, seed, grid_size))
# Out:
# <PIL.Image.Image image mode=RGB size=512x512>
# CPU times: user 30.2 s, sys: 208 ms, total: 30.4 s
# Wall time: 30.4 s

# %%
# %%time

text = "angry boy"
seed = 6
grid_size = 2

display(model.generate_image(text, seed, grid_size))
# Out:
# <PIL.Image.Image image mode=RGB size=512x512>
# CPU times: user 30.8 s, sys: 259 ms, total: 31 s
# Wall time: 31.1 s

# %%
# %%time

text = "happy girl"
seed = 42
grid_size = 2

display(model.generate_image(text, seed, grid_size))
# Out:
# <PIL.Image.Image image mode=RGB size=512x512>
# CPU times: user 31.3 s, sys: 298 ms, total: 31.6 s
# Wall time: 31.7 s

# %% [markdown]
# Mini-dalle добре справляється з генерацією конкретних об'єктів та бекграундів (ландшафтів), але з генерацією людей виникають труднощі, хоча емоція розпізнається доволі добре.
