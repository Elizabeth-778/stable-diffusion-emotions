# %% [markdown]
# Fooocus https://github.com/lllyasviel/Fooocus
# Stable diffusion + Midjourney

# %%
# !pip install pygit2==1.12.2
# %cd /content
# !git clone https://github.com/lllyasviel/Fooocus.git
# %cd /content/Fooocus
# !python entry_with_update.py --share --always-high-vram
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 16.5 MB/s eta 0:00:00
# ...
# /content
# Cloning into 'Fooocus'...
# remote: Enumerating objects: 5849, done.
# remote: Counting objects: 100% (14/14), done.
# remote: Compressing objects: 100% (13/13), done.
# remote: Total 5849 (delta 1), reused 7 (delta 1), pack-reused 5835
# Receiving objects: 100% (5849/5849), 32.67 MiB | 31.35 MiB/s, done.
# Resolving deltas: 100% (3372/3372), done.
# /content/Fooocus
# Already up-to-date
# Update succeeded.
# [System ARGV] ['entry_with_update.py', '--share', '--always-high-vram']
# Python 3.10.12 (main, Nov 20 2023, 15:14:05) [GCC 11.4.0]
# Fooocus version: 2.3.1
# Error checking version for torchsde: No package metadata was found for torchsde
# Installing requirements
# [Cleanup] Attempting to delete content of temp dir /tmp/fooocus
# [Cleanup] Cleanup successful
# ...

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# EmoGen https://github.com/JingyuanYY/EmoGen/tree/master
# Також я намагалась запустити модель EmoGen, але нажаль не вийшло через те що yaml file був створений під linux 64, а у мене macos arm 64, тому багато пекеджей не скачувались та через це не зміг створитись конда енв. \\
# Архітектура \\
# ![image.png](data:image/png;base64,...)
